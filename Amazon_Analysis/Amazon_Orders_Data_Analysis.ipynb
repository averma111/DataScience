# %%
import pandas as pd
import numpy as np

# %%
# Read amazon data in csv format

amazon_df = pd.read_csv('data/amazon_data.csv')
amazon_df
# Out:
#     Order Date             Order ID Payment Instrument Type     Website  \
# 0     04/01/17  114-7377770-5441803             Visa - 8107  Amazon.com
# 1     04/10/17  114-4031591-1786643             Visa - 8107  Amazon.com
# 2     04/15/17  114-9969225-1723431             Visa - 8107  Amazon.com
# 3     04/22/17  114-1688470-0627438       MasterCard - 0738  Amazon.com
# 4     04/30/17  114-4417677-6195403       MasterCard - 0738  Amazon.com
# ..         ...                  ...                     ...         ...
# 329   09/26/21  111-6210541-9748237       MasterCard - 0160  Amazon.com
# 330   09/26/21  111-6210541-9748237       MasterCard - 0160  Amazon.com
# 331   10/01/21  114-3521784-2089065       MasterCard - 0160  Amazon.com
# 332   10/04/21  114-4914056-3826654       MasterCard - 0160  Amazon.com
# 333   10/10/21  112-3249034-5842634       MasterCard - 0160  Amazon.com
#
#      Purchase Order Number Ordering Customer Email Shipment Date  \
# ...

# %%
amazon_df.shape
# Out:
# (334, 23)

# %%
# Cleaning the NAN values
amazon_df.fillna(0)
# Out:
#     Order Date             Order ID Payment Instrument Type     Website  \
# 0     04/01/17  114-7377770-5441803             Visa - 8107  Amazon.com
# 1     04/10/17  114-4031591-1786643             Visa - 8107  Amazon.com
# 2     04/15/17  114-9969225-1723431             Visa - 8107  Amazon.com
# 3     04/22/17  114-1688470-0627438       MasterCard - 0738  Amazon.com
# 4     04/30/17  114-4417677-6195403       MasterCard - 0738  Amazon.com
# ..         ...                  ...                     ...         ...
# 329   09/26/21  111-6210541-9748237       MasterCard - 0160  Amazon.com
# 330   09/26/21  111-6210541-9748237       MasterCard - 0160  Amazon.com
# 331   10/01/21  114-3521784-2089065       MasterCard - 0160  Amazon.com
# 332   10/04/21  114-4914056-3826654       MasterCard - 0160  Amazon.com
# 333   10/10/21  112-3249034-5842634       MasterCard - 0160  Amazon.com
#
#      Purchase Order Number Ordering Customer Email Shipment Date  \
# ...

# %%
amazon_df.columns
# Out:
# Index(['Order Date', 'Order ID', 'Payment Instrument Type', 'Website',
#        'Purchase Order Number', 'Ordering Customer Email', 'Shipment Date',
#        'Shipping Address Name', 'Shipping Address Street 1',
#        'Shipping Address Street 2', 'Shipping Address City',
#        'Shipping Address State', 'Shipping Address Zip', 'Order Status',
#        'Carrier Name & Tracking Number', 'Subtotal', 'Shipping Charge',
#        'Tax Before Promotions', 'Total Promotions', 'Tax Charged',
#        'Total Charged', 'Buyer Name', 'Group Name'],
#       dtype='object')

# %%
amazon_df['Total Charged'] = amazon_df['Total Charged'].str.replace('$','').astype(float)
# Out:
# <ipython-input-9-605eff2885cf>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   amazon_df['Total Charged'] = amazon_df['Total Charged'].str.replace('$','').astype(float)

# %%
amazon_df['Total Charged']
# Out:
# 0      97.29
# 1      58.32
# 2      23.48
# 3      20.99
# 4      19.95
#        ...
# 329    39.52
# 330    22.14
# 331     9.96
# 332     8.84
# 333      NaN
# Name: Total Charged, Length: 334, dtype: float64

# %%
# Finding the total amount spent on amazon orders
amazon_df['Total Charged'].sum()

#11207.64
# Out:
# 11207.64

# %%
#Finding the meam value of amount spent
amazon_df['Total Charged'].mean()
# Out:
# 33.656576576576526

# %%
#Finding the meam value of amount spent
amazon_df['Total Charged'].median()
# Out:
# 18.99

# %%
amazon_df['Tax Charged'] = amazon_df['Tax Charged'].str.replace('$','').astype(float)
# Out:
# <ipython-input-14-4ba9d9d22fe6>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   amazon_df['Tax Charged'] = amazon_df['Tax Charged'].str.replace('$','').astype(float)

# %%
# Total tax charged from buying goods from amazon
amazon_df['Tax Charged'].sum()
# Out:
# 682.24

# %%
amazon_df['Order Date'] = pd.to_datetime(amazon_df['Order Date'])

# %%
# %matplotlib inline

# %%
yearly_orders = amazon_df.groupby(amazon_df['Order Date'].map(lambda x: x.year)).sum()["Total Charged"]

# %%
yearly_orders
# Out:
# Order Date
# 2017    2181.19
# 2018    1880.81
# 2019    1308.56
# 2020    1306.16
# 2021    4530.92
# Name: Total Charged, dtype: float64

# %%
yearly_orders.plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>
